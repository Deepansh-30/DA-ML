# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv('C:\DML PROJECT\Project-on-prediction-in-blood-pressure\Assignment\heartclean.csv')

# %% [markdown]
# ## Handle categorical variables with numerically coded values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       995 non-null    int64
#  1   sex       995 non-null    int64
#  2   cp        995 non-null    int64
#  3   trestbps  995 non-null    int64
#  4   chol      995 non-null    int64
#  5   fbs       995 non-null    int64
#  6   restecg   995 non-null    int64
#  7   thalach   995 non-null    int64
#  8   exang     995 non-null    int64
#  9   oldpeak   995 non-null    float64
#  10  slope     995 non-null    int64
#  11  ca        995 non-null    float64
#  12  thal      995 non-null    int64
#  13  target    995 non-null    int64
# dtypes: float64(2), int64(12)
# memory usage: 109.0 KB

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     48
# chol        150
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      39
# slope         3
# ca            4
# thal          4
# target        2
# dtype: int64

# %% [markdown]
# ## All the 14 attributes are categarical variables as I have already converted it into categorial variable which cleaning my dataset

# %% [markdown]
# ## Perform univariate and bivariate analysis and derive meaningful insights about the dataset

# %%
df['age'].plot.hist()
plt.xlabel('AGE')
plt.ylabel('FREQUENCY')
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %% [markdown]
# ## Checking the frequency of different ages

# %%
plt.bar(df['age'], df['target']) 
plt.show()

# %%
plt.pie(df['age'], df['target']) 
plt.show()

# %%
var = df.groupby(['age','sex']).target.sum()
var.unstack().plot(kind='bar',stacked=True,  color=['red','blue'], grid=False)

# %% [markdown]
# ## Comparing age column with target column

# %%
g=sns.FacetGrid(df,col='target')
g=g.map(sns.distplot,"age")
plt.show()

# %%
sns.set_style('darkgrid')
df['sex'].plot.hist()
plt.xlabel('SEX')
plt.ylabel('FREQUENCY')
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
g1=sns.FacetGrid(df,col='target')
g1=g1.map(sns.distplot,"sex")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-64c2df19be69> in <module>
#       1 g1=sns.FacetGrid(df,col='target')
# ----> 2 g1=g1.map(sns.distplot,"sex")
#       3 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     765
#     766             # Draw the plot
# --> 767             self._facet_plot(func, ax, plot_args, kwargs)
#     768
# ...

# %%
df.groupby('sex').target.mean().plot(kind='bar')

# %%
g1=sns.FacetGrid(df,col='target')
g1=g1.map(sns.distplot,"cp")
plt.show()

# %%
df.groupby('cp').target.mean().plot(kind='bar')

# %%
df['trestbps'].plot(kind='hist',stacked=True)
plt.xlabel('TRESTBPS')
plt.ylabel('FREQUENCY')
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
g1=sns.FacetGrid(df,col='target')
g1=g1.map(sns.distplot,"trestbps")
plt.show()

# %%
df.groupby('trestbps').target.mean().plot(kind='bar')

# %%
df['chol'].plot(kind='hist',stacked=True)
plt.xlabel('CHOL')
plt.ylabel('FREQUENCY')
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
g1=sns.FacetGrid(df,col='target')
g1=g1.map(sns.distplot,"chol")
plt.show()

# %%
df.groupby('chol').target.mean().plot(kind='bar')

# %%
df['fbs'].plot(kind='hist',stacked=True)
plt.xlabel('fbs')
plt.ylabel('FREQUENCY')
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
g1=sns.FacetGrid(df,col='target')
g1=g1.map(sns.distplot,"fbs")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-f0a916323ec4> in <module>
#       1 g1=sns.FacetGrid(df,col='target')
# ----> 2 g1=g1.map(sns.distplot,"fbs")
#       3 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     765
#     766             # Draw the plot
# --> 767             self._facet_plot(func, ax, plot_args, kwargs)
#     768
# ...

# %%
df.groupby('fbs').target.mean().plot(kind='bar')

# %%
df['restecg'].plot(kind='hist',stacked=True)
plt.xlabel('restecg')
plt.ylabel('FREQUENCY')
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
g1=sns.FacetGrid(df,col='target')
g1=g1.map(sns.distplot,"restecg")
plt.show()

# %%
df.groupby('restecg').target.mean().plot(kind='bar')

# %%
df['thalach'].plot(kind='hist',stacked=True)
plt.xlabel('thalach')
plt.ylabel('FREQUENCY')
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
g1=sns.FacetGrid(df,col='target')
g1=g1.map(sns.distplot,"thalach")
plt.show()

# %%
df.groupby('thalach').target.mean().plot(kind='bar')

# %%
df['exang'].plot(kind='hist',stacked=True)
plt.xlabel('exang')
plt.ylabel('FREQUENCY')
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
g1=sns.FacetGrid(df,col='target')
g1=g1.map(sns.distplot,"exang")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-30-34f1317969f7> in <module>
#       1 g1=sns.FacetGrid(df,col='target')
# ----> 2 g1=g1.map(sns.distplot,"exang")
#       3 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     765
#     766             # Draw the plot
# --> 767             self._facet_plot(func, ax, plot_args, kwargs)
#     768
# ...

# %%
df.groupby('exang').target.mean().plot(kind='bar')

# %%
df['oldpeak'].plot(kind='hist',stacked=True)
plt.xlabel('oldpeak')
plt.ylabel('FREQUENCY')
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
g1=sns.FacetGrid(df,col='target')
g1=g1.map(sns.distplot,"oldpeak")
plt.show()

# %%
df.groupby('oldpeak').target.mean().plot(kind='bar')

# %%
df['slope'].plot(kind='hist',stacked=True)
plt.xlabel('slope')
plt.ylabel('FREQUENCY')
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
g1=sns.FacetGrid(df,col='target')
g1=g1.map(sns.distplot,"slope")
plt.show()

# %%
df.groupby('slope').target.mean().plot(kind='bar')

# %%
df['ca'].plot(kind='hist',stacked=True)
plt.xlabel('ca')
plt.ylabel('FREQUENCY')
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
g1=sns.FacetGrid(df,col='target')
g1=g1.map(sns.distplot,"ca")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-39-2d56923f8383> in <module>
#       1 g1=sns.FacetGrid(df,col='target')
# ----> 2 g1=g1.map(sns.distplot,"ca")
#       3 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     765
#     766             # Draw the plot
# --> 767             self._facet_plot(func, ax, plot_args, kwargs)
#     768
# ...

# %%
df.groupby('ca').target.mean().plot(kind='bar')

# %%
df['thal'].plot(kind='hist',stacked=True)
plt.xlabel('thal')
plt.ylabel('FREQUENCY')
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
g1=sns.FacetGrid(df,col='target')
g1=g1.map(sns.distplot,"thal")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-42-b0729a47091c> in <module>
#       1 g1=sns.FacetGrid(df,col='target')
# ----> 2 g1=g1.map(sns.distplot,"thal")
#       3 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     765
#     766             # Draw the plot
# --> 767             self._facet_plot(func, ax, plot_args, kwargs)
#     768
# ...

# %%
df.groupby('thal').target.mean().plot(kind='bar')

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# age         13.0
# sex          1.0
# cp           2.0
# trestbps    20.0
# chol        64.0
# fbs          0.0
# restecg      1.0
# thalach     33.0
# exang        1.0
# oldpeak      1.8
# slope        1.0
# ca           1.0
# thal         1.0
# target       1.0
# dtype: float64

# %%
df.groupby('trestbps')["trestbps"].count()
sns.barplot(df,df.index,orient='v',ci=0,palette='Spectral')
plt.xlabel("trestbps")
plt.ylabel("No of entries")
plt.title("trestbps vs. Entries graph")
plt.xticks(np.arange(7),('chol', 'fbs','restecg', 'thalach', 'exang','oldpeak', 'slope'))
plt.xticks(rotation=45)
plt.yticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py in categorical_order(values, order)
#     530             try:
# --> 531                 order = values.cat.categories
#     532             except (TypeError, AttributeError):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#
# AttributeError: 'DataFrame' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py in categorical_order(values, order)
#     533                 try:
# ...

# %%
sns.boxplot(df['age'])

# %%
sns.boxplot(df['sex'])

# %%
sns.boxplot(df['cp'])

# %%
sns.boxplot(df['ca'])

# %%
sns.boxplot(df['thal'])

# %%
sns.boxplot(df['fbs'])

# %%
sns.boxplot(df['restecg'])

# %%
sns.boxplot(df['chol'])

# %%
sns.boxplot(df['thalach'])

# %%
sns.boxplot(df['exang'])

# %%
sns.boxplot(df['slope'])

# %%
sns.boxplot(df['oldpeak'])

# %% [markdown]
# ## Build a correlation matrix to identify relevant variables ( Graph)

# %%
sns.pairplot(df)

# %%
correlation=df.corr()
correlation
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.090735 -0.054426  0.284216  0.203187  0.131317
# sex      -0.090735  1.000000 -0.056662 -0.055315 -0.170481  0.040740
# cp       -0.054426 -0.056662  1.000000  0.056349 -0.061783  0.099263
# trestbps  0.284216 -0.055315  0.056349  1.000000  0.116150  0.157254
# chol      0.203187 -0.170481 -0.061783  0.116150  1.000000  0.017496
# fbs       0.131317  0.040740  0.099263  0.157254  0.017496  1.000000
# restecg  -0.120289 -0.073009  0.020613 -0.109732 -0.129682 -0.088560
# thalach  -0.384889 -0.058830  0.298232 -0.034797 -0.011682  0.003656
# exang     0.083188  0.148064 -0.392893  0.043847  0.071112  0.024005
# oldpeak   0.183817  0.124227 -0.148136  0.148283  0.027727 -0.003825
# slope    -0.161644 -0.052108  0.116022 -0.095350  0.016567 -0.033950
# ca        0.358760  0.104729 -0.212434  0.075990  0.108579  0.147423
# thal      0.060126  0.212792 -0.146763  0.041301  0.088063 -0.059065
# ...

# %%
plt.subplots(figsize=(5,5))
sns.heatmap(correlation)

# %%
feature_cols = ['age','sex','cp','trestbps','chol','fbs','restbps','thalach','exang','oldpeak','slope','ca','thal']

# %%
X=df.iloc[:,:-1].values #dependent
y=df.iloc[:,-1].values  #independent

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=9)
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter = 10000)
logreg=logreg.fit(X_train,y_train)
y_pred=logreg.predict(X_test)

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[77, 17],
#        [14, 91]], dtype=int64)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.8442211055276382
# Precision: 0.8425925925925926
# Recall: 0.8666666666666667

# %%
y_pred_proba = logreg.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()
#AUC score for the case is 0.86. AUC score 1 represents perfect classifier, and 0.5 represents a worthless classifier.

# %% [markdown]
# # DECISION TREE

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %% [markdown]
# # RANDOM FOREST

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %% [markdown]
# # K NEIGHBOUR

# %%
#Import knearest neighbors Classifier model
from sklearn.neighbors import KNeighborsClassifier

#Create KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5)

#Train the model using the training sets
knn.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = knn.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7386934673366834

# %%
#Import knearest neighbors Classifier model
from sklearn.neighbors import KNeighborsClassifier

#Create KNN Classifier
knn = KNeighborsClassifier(n_neighbors=10)

#Train the model using the training sets
knn.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = knn.predict(X_test)
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7286432160804021

# %%
knn.predict([[34,0,1,135,200,0,1,250,0,147,0,1,3]])
# Out:
# array([1], dtype=int64)

# %%
k=clf.predict([[59,1,1,149,227,1,2,258,1,50,1,0,2]])
k[0]
# Out:
# 0

# %%
logreg.predict([[22,1,3,115,229,0,2,127,1,499,1,0,3]])
# Out:
# array([0], dtype=int64)

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import *
a,b,c,d,e,f,g,h=0,0,0,0,0,0,0,0

target=0


def callbackFunc(event):
    global a ,b ,c ,c,d,e,f,g,h
    a=l1.index(comboExample1.get())
    b=l2.index(comboExample2.get())
    c=l3.index(comboExample3.get())
    d=l4.index(comboExample4.get())
    e=l5.index(comboExample5.get())
    f=l6.index(comboExample6.get())
    g=l7.index(comboExample7.get())
    h=l8.index(comboExample8.get())
     

def submit():
    i,j,n,l,m=0,0,0,0,0
    if age.get().isnumeric() and trestbps.get().isnumeric() and chol.get().isnumeric() and thalach.get().isnumeric() and oldpeak.get():
        i=int(age.get())
        j=int(trestbps.get())
        n=int(chol.get())
        l=int(thalach.get())
        m=float(oldpeak.get())
        out=0
        k=clf.predict([[i,c,e,g,h,f,d,b,a,j,n,l,m]])
        out=k[0]
        app1 = tk.Tk() 
        app1.geometry('650x300')
        app1.title('OUTPUT')
        if out==0:
            label_out = tk.Label(app1,text=msg0,font=('georgia', 30),relief='raised').place(x=50,y=50)
        else:
            label_out = tk.Label(app1,text=msg1,font=('georgia', 30),relief='raised').place(x=50,y=50)
        app1.mainloop()
    else:
        app2 = tk.Tk() 
        app2.geometry('650x200')
        app2.title('Warning')
        label_war = tk.Label(app2,text=msgw,font=('cambria',20,'bold')).place(x=25,y=25)
        age.delete(0,END)
        trestbps.delete(0,END)
        chol.delete(0,END)
        thalach.delete(0,END)
        oldpeak.delete(0,END)
        app2.mainloop()

   # print(a, b, c, d, e, f, g, i, j )  #59,0,13,1,7,3,3,1,50


app = tk.Tk() 
app.geometry('1000x1000')
app.configure(background='blue')
app.title('HEART DISEASE PREDICTOR')

msg='According to Random Forest Classifier Algorithm \n with a accuracy score of 100% '

msg1='Patient is suffering from heart disease'

msg0='Patient is not suffering from heart disease'

msgw='Please enter Integer value only.'



label_title = tk.Label(app, text = "Heart disease Predictor ",font=('Times', 24)).grid(column=1, row=0)
label_file = tk.Label(app, text = " ",font=('Times', 16)).grid(column=0, row=1)
label_file1 = tk.Label(app, text = " ",font=('Times', 16)).grid(column=0, row=2)
label_inst = tk.Label(app, text = "Choose all desired attributes..",font=('Times', 14)).place(x=20,y=60)
label_def = tk.Label(app, text = msg,font=('Times', 12)).place(x=210,y=500)


label_1 = tk.Label(app, text = "Gender",font=('georgia', 14)).grid(column=0, row=3)
label_2 = tk.Label(app, text = "cp",font=('georgia', 14)).grid(column=1, row=3)
label_3 = tk.Label(app, text = "fbs",font=('georgia', 14)).grid(column=2, row=3)
label_4 = tk.Label(app, text = "Restecg",font=('georgia', 14)).grid(column=0, row=5)
label_5 = tk.Label(app, text = "exang",font=('georgia', 14)).grid(column=1, row=5)
label_6 = tk.Label(app, text = "slope",font=('georgia', 14)).grid(column=2, row=5)
label_7 = tk.Label(app, text = "ca",font=('georgia', 14)).grid(column=0, row=7)
label_8 = tk.Label(app, text = "thal",font=('georgia', 14)).grid(column=1, row=7)
label_age = tk.Label(app, text = "Age",font=('georgia', 14)).grid(column=2, row=7)
label_trestbps = tk.Label(app, text = "trestbps",font=('georgia', 14)).grid(column=0, row=9)
label_chol = tk.Label(app, text = "chol",font=('georgia', 14)).grid(column=1, row=9)
label_thalach = tk.Label(app, text = "thalach",font=('georgia', 14)).grid(column=2, row=9)
label_oldpeak = tk.Label(app, text = "oldpeak",font=('georgia', 14)).grid(column=0, row=11)




l1=['0','1']

l2=[' 0', ' 1',' 2',' 3']

l3=['0','1']

l4=['0','1','2']

l5=['0','1']

l6=[' 0',' 1',' 2']

l7=['0','1','2','3']

l8=['0','1','2','3']

comboExample1 = ttk.Combobox(app, values=l1,state='readonly')
comboExample2 = ttk.Combobox(app,values=l2,state='readonly')
comboExample3 = ttk.Combobox(app,values=l3,state='readonly')
comboExample4 = ttk.Combobox(app, values=l4,state='readonly')
comboExample5 = ttk.Combobox(app,values=l5,state='readonly')
comboExample6 = ttk.Combobox(app,values=l6,state='readonly')
comboExample7 = ttk.Combobox(app,values=l7,state='readonly')
comboExample8 = ttk.Combobox(app,values=l8,state='readonly')


comboExample1.grid(column=0, row=4,padx=20,pady=10)
comboExample2.grid(column=1, row=4,padx=40,pady=10)
comboExample3.grid(column=2, row=4,pady=10)
comboExample4.grid(column=0, row=6,padx=20,pady=20)
comboExample5.grid(column=1, row=6,padx=40,pady=10)
comboExample6.grid(column=2, row=6,pady=10)
comboExample7.grid(column=0, row=8,padx=20,pady=20)
comboExample8.grid(column=1, row=8,padx=40,pady=10)


comboExample1.current(0)
comboExample2.current(0)
comboExample3.current(0)
comboExample4.current(0)
comboExample5.current(0)
comboExample6.current(0)
comboExample7.current(0)
comboExample8.current(0)

    
    
                      
comboExample1.bind("<<ComboboxSelected>>", callbackFunc)
comboExample2.bind("<<ComboboxSelected>>", callbackFunc)
comboExample3.bind("<<ComboboxSelected>>", callbackFunc)
comboExample4.bind("<<ComboboxSelected>>", callbackFunc)
comboExample5.bind("<<ComboboxSelected>>", callbackFunc)
comboExample6.bind("<<ComboboxSelected>>", callbackFunc)
comboExample7.bind("<<ComboboxSelected>>", callbackFunc)
comboExample8.bind("<<ComboboxSelected>>", callbackFunc)



age=tk.Entry(app)
trestbps=tk.Entry(app)
chol=tk.Entry(app)
thalach=tk.Entry(app)
oldpeak=tk.Entry(app)

age.grid(column=2, row=8,pady=10)
trestbps.grid(column=0, row=10,padx=40,pady=10)
chol.grid(column=1, row=10,padx=40,pady=10)
thalach.grid(column=2, row=10,pady=10)
oldpeak.grid(column=0, row=12,padx=40,pady=10)


Button(app, text='SUBMIT', font=('aprajita', 18, ''),bg='#8B7D6B', command=submit).grid(column=1,row=12)


#label_out = tk.Label(app,text=msg0,font=('Times', 24),relief='raised',bg='#8B7D6B').place(x=380,y=380)


app.mainloop()
